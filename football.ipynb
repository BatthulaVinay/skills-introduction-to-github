# %%
import pandas as pd
matches = pd.read_csv("matches.csv", index_col=0)
matches.head()
# Out:
#                   date   time            comp        round  day venue result  \
# Unnamed: 0
# 1           2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L
# 2           2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W
# 3           2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W
# 4           2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W
# 6           2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D
#
#              gf   ga        opponent  ...   fk   pk  pkatt  season  \
# Unnamed: 0                            ...
# 1           0.0  1.0       Tottenham  ...  1.0  0.0    0.0    2022
# 2           5.0  0.0    Norwich City  ...  1.0  0.0    0.0    2022
# 3           5.0  0.0         Arsenal  ...  0.0  0.0    0.0    2022
# 4           1.0  0.0  Leicester City  ...  0.0  0.0    0.0    2022
# 6           0.0  0.0     Southampton  ...  1.0  0.0    0.0    2022
#
#                        team venue_code opp_code hour  day_code  target
# Unnamed: 0
# 1           Manchester City          0       18   16         6       0
# 2           Manchester City          1       15   15         5       1
# 3           Manchester City          1        0   12         5       1
# 4           Manchester City          0       10   15         5       1
# 6           Manchester City          1       17   15         5       0
#
# [5 rows x 32 columns]

# %%
matches.shape
# Out:
# (1389, 32)

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#                   date   time            comp         round  day venue result  \
# Unnamed: 0
# 1           2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W
# 2           2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W
# 4           2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W
# 6           2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L
# 7           2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D
# 9           2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W
# 11          2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W
# 13          2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D
# 14          2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W
# 16          2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D
# 18          2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W
# 20          2020-12-13  16:30  Premier League  Matchweek 12  Sun  Away      D
# 21          2020-12-16  20:00  Premier League  Matchweek 13  Wed  Home      W
# 22          2020-12-19  12:30  Premier League  Matchweek 14  Sat  Away      W
# 23          2020-12-27  16:30  Premier League  Matchweek 15  Sun  Home      D
# 24          2020-12-30  20:00  Premier League  Matchweek 16  Wed  Away      D
# 25          2021-01-04  20:00  Premier League  Matchweek 17  Mon  Away      L
# 27          2021-01-17  16:30  Premier League  Matchweek 19  Sun  Home      D
# 28          2021-01-21  20:00  Premier League  Matchweek 18  Thu  Home      L
# 30          2021-01-28  20:00  Premier League  Matchweek 20  Thu  Away      W
# 31          2021-01-31  16:30  Premier League  Matchweek 21  Sun  Away      W
# 32          2021-02-03  20:15  Premier League  Matchweek 22  Wed  Home      L
# 33          2021-02-07  16:30  Premier League  Matchweek 23  Sun  Home      L
# 34          2021-02-13  12:30  Premier League  Matchweek 24  Sat  Away      L
# 36          2021-02-20  17:30  Premier League  Matchweek 25  Sat  Home      L
# 37          2021-02-28  19:15  Premier League  Matchweek 26  Sun  Away      W
# 38          2021-03-04  20:15  Premier League  Matchweek 29  Thu  Home      L
# 39          2021-03-07  14:00  Premier League  Matchweek 27  Sun  Home      L
# 41          2021-03-15  20:00  Premier League  Matchweek 28  Mon  Away      W
# 42          2021-04-03  20:00  Premier League  Matchweek 30  Sat  Away      W
# 44          2021-04-10  15:00  Premier League  Matchweek 31  Sat  Home      W
# 46          2021-04-19  20:00  Premier League  Matchweek 32  Mon  Away      D
# 47          2021-04-24  12:30  Premier League  Matchweek 33  Sat  Home      D
# 48          2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W
# 49          2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W
# 50          2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W
# 51          2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W
# 52          2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W
#
#              gf   ga         opponent  ...   fk   pk  pkatt  season  \
# Unnamed: 0                             ...
# 1           4.0  3.0     Leeds United  ...  0.0  2.0    2.0    2021
# 2           2.0  0.0          Chelsea  ...  1.0  0.0    0.0    2021
# 4           3.0  1.0          Arsenal  ...  0.0  0.0    0.0    2021
# 6           2.0  7.0      Aston Villa  ...  1.0  0.0    0.0    2021
# 7           2.0  2.0          Everton  ...  1.0  0.0    0.0    2021
# 9           2.0  1.0    Sheffield Utd  ...  1.0  0.0    0.0    2021
# 11          2.0  1.0         West Ham  ...  1.0  1.0    1.0    2021
# 13          1.0  1.0  Manchester City  ...  0.0  1.0    1.0    2021
# 14          3.0  0.0   Leicester City  ...  0.0  0.0    0.0    2021
# 16          1.0  1.0         Brighton  ...  0.0  0.0    0.0    2021
# 18          4.0  0.0           Wolves  ...  1.0  0.0    0.0    2021
# 20          1.0  1.0           Fulham  ...  1.0  1.0    1.0    2021
# 21          2.0  1.0        Tottenham  ...  0.0  0.0    0.0    2021
# 22          7.0  0.0   Crystal Palace  ...  1.0  0.0    0.0    2021
# 23          1.0  1.0        West Brom  ...  2.0  0.0    0.0    2021
# 24          0.0  0.0    Newcastle Utd  ...  0.0  0.0    0.0    2021
# 25          0.0  1.0      Southampton  ...  0.0  0.0    0.0    2021
# 27          0.0  0.0   Manchester Utd  ...  0.0  0.0    0.0    2021
# 28          0.0  1.0          Burnley  ...  0.0  0.0    0.0    2021
# 30          3.0  1.0        Tottenham  ...  0.0  0.0    0.0    2021
# 31          3.0  1.0         West Ham  ...  0.0  0.0    0.0    2021
# 32          0.0  1.0         Brighton  ...  0.0  0.0    0.0    2021
# 33          1.0  4.0  Manchester City  ...  1.0  1.0    1.0    2021
# 34          1.0  3.0   Leicester City  ...  2.0  0.0    0.0    2021
# 36          0.0  2.0          Everton  ...  1.0  0.0    0.0    2021
# 37          2.0  0.0    Sheffield Utd  ...  0.0  0.0    0.0    2021
# 38          0.0  1.0          Chelsea  ...  0.0  0.0    0.0    2021
# 39          0.0  1.0           Fulham  ...  1.0  0.0    0.0    2021
# 41          1.0  0.0           Wolves  ...  0.0  0.0    0.0    2021
# 42          3.0  0.0          Arsenal  ...  0.0  0.0    0.0    2021
# 44          2.0  1.0      Aston Villa  ...  1.0  0.0    0.0    2021
# 46          1.0  1.0     Leeds United  ...  0.0  0.0    0.0    2021
# 47          1.0  1.0    Newcastle Utd  ...  1.0  0.0    0.0    2021
# 48          2.0  0.0      Southampton  ...  0.0  0.0    0.0    2021
# 49          4.0  2.0   Manchester Utd  ...  0.0  0.0    0.0    2021
# 50          2.0  1.0        West Brom  ...  1.0  0.0    0.0    2021
# 51          3.0  0.0          Burnley  ...  1.0  0.0    0.0    2021
# 52          2.0  0.0   Crystal Palace  ...  1.0  0.0    0.0    2021
#
#                  team venue_code opp_code hour  day_code  target
# Unnamed: 0
# 1           Liverpool          1        9   17         5       1
# 2           Liverpool          0        5   16         6       1
# 4           Liverpool          1        0   20         0       1
# 6           Liverpool          0        1   19         6       0
# 7           Liverpool          0        7   12         5       0
# 9           Liverpool          1       16   20         5       1
# 11          Liverpool          1       21   17         5       1
# 13          Liverpool          0       12   16         6       0
# 14          Liverpool          1       10   19         6       1
# 16          Liverpool          0        3   12         5       0
# 18          Liverpool          1       22   19         6       1
# 20          Liverpool          0        8   16         6       0
# 21          Liverpool          1       18   20         2       1
# 22          Liverpool          0        6   12         5       1
# 23          Liverpool          1       20   16         6       0
# 24          Liverpool          0       14   20         2       0
# 25          Liverpool          0       17   20         0       0
# 27          Liverpool          1       13   16         6       0
# 28          Liverpool          1        4   20         3       0
# 30          Liverpool          0       18   20         3       1
# 31          Liverpool          0       21   16         6       1
# 32          Liverpool          1        3   20         2       0
# 33          Liverpool          1       12   16         6       0
# 34          Liverpool          0       10   12         5       0
# 36          Liverpool          1        7   17         5       0
# 37          Liverpool          0       16   19         6       1
# 38          Liverpool          1        5   20         3       0
# 39          Liverpool          1        8   14         6       0
# 41          Liverpool          0       22   20         0       1
# 42          Liverpool          0        0   20         5       1
# 44          Liverpool          1        1   15         5       1
# 46          Liverpool          0        9   20         0       0
# 47          Liverpool          1       14   12         5       0
# 48          Liverpool          1       17   20         5       1
# 49          Liverpool          0       13   20         3       1
# 50          Liverpool          0       20   16         6       1
# 51          Liverpool          0        4   20         2       1
# 52          Liverpool          1        6   16         6       1
#
# [38 rows x 32 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# venue_code        int64
# opp_code          int64
# hour              int64
# day_code          int64
# target            int64
# dtype: object

# %%
del matches["comp"]
del matches["notes"]
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#                  date   time         round  day venue result   gf   ga  \
# Unnamed: 0
# 1          2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2          2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3          2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4          2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6          2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ...               ...    ...           ...  ...   ...    ...  ...  ...
# 38         2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39         2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40         2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41         2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42         2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#                   opponent   xg  ...   fk   pk  pkatt season  \
# Unnamed: 0                       ...
# 1                Tottenham  1.9  ...  1.0  0.0    0.0   2022
# 2             Norwich City  2.7  ...  1.0  0.0    0.0   2022
# 3                  Arsenal  3.8  ...  0.0  0.0    0.0   2022
# 4           Leicester City  2.9  ...  0.0  0.0    0.0   2022
# 6              Southampton  1.1  ...  1.0  0.0    0.0   2022
# ...                    ...  ...  ...  ...  ...    ...    ...
# 38               Tottenham  0.5  ...  0.0  0.0    0.0   2021
# 39          Crystal Palace  0.7  ...  1.0  0.0    0.0   2021
# 40                 Everton  1.6  ...  0.0  0.0    0.0   2021
# 41           Newcastle Utd  0.8  ...  1.0  0.0    0.0   2021
# 42                 Burnley  0.6  ...  0.0  0.0    0.0   2021
#
#                         team venue_code opp_code  hour  day_code  target
# Unnamed: 0
# 1            Manchester City          0       18    16         6       0
# 2            Manchester City          1       15    15         5       1
# 3            Manchester City          1        0    12         5       1
# 4            Manchester City          0       10    15         5       1
# 6            Manchester City          1       17    15         5       0
# ...                      ...        ...      ...   ...       ...     ...
# 38          Sheffield United          0       18    19         6       0
# 39          Sheffield United          1        6    15         5       0
# 40          Sheffield United          0        7    19         6       1
# 41          Sheffield United          0       14    18         2       0
# 42          Sheffield United          1        4    16         6       1
#
# [1389 rows x 30 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#                  date   time         round  day venue result   gf   ga  \
# Unnamed: 0
# 1          2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2          2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3          2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4          2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6          2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ...               ...    ...           ...  ...   ...    ...  ...  ...
# 38         2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39         2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40         2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41         2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42         2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#                   opponent   xg  ...   fk   pk  pkatt season  \
# Unnamed: 0                       ...
# 1                Tottenham  1.9  ...  1.0  0.0    0.0   2022
# 2             Norwich City  2.7  ...  1.0  0.0    0.0   2022
# 3                  Arsenal  3.8  ...  0.0  0.0    0.0   2022
# 4           Leicester City  2.9  ...  0.0  0.0    0.0   2022
# 6              Southampton  1.1  ...  1.0  0.0    0.0   2022
# ...                    ...  ...  ...  ...  ...    ...    ...
# 38               Tottenham  0.5  ...  0.0  0.0    0.0   2021
# 39          Crystal Palace  0.7  ...  1.0  0.0    0.0   2021
# 40                 Everton  1.6  ...  0.0  0.0    0.0   2021
# 41           Newcastle Utd  0.8  ...  1.0  0.0    0.0   2021
# 42                 Burnley  0.6  ...  0.0  0.0    0.0   2021
#
#                         team venue_code opp_code  hour  day_code  target
# Unnamed: 0
# 1            Manchester City          0       18    16         6       0
# 2            Manchester City          1       15    15         5       1
# 3            Manchester City          1        0    12         5       1
# 4            Manchester City          0       10    15         5       1
# 6            Manchester City          1       17    15         5       0
# ...                      ...        ...      ...   ...       ...     ...
# 38          Sheffield United          0       18    19         6       0
# 39          Sheffield United          1        6    15         5       0
# 40          Sheffield United          0        7    19         6       1
# 41          Sheffield United          0       14    18         2       0
# 42          Sheffield United          1        4    16         6       1
#
# [1389 rows x 30 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
preds = rf.predict(test[predictors])
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#                  date   time         round  day venue result   gf   ga  \
# Unnamed: 0
# 5          2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7          2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9          2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 11         2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 12         2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ...               ...    ...           ...  ...   ...    ...  ...  ...
# 42         2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44         2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46         2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49         2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50         2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#                   opponent   xg  ...  day_code  target  gf_rolling ga_rolling  \
# Unnamed: 0                       ...
# 5                  Arsenal  1.5  ...         5       1    2.000000   2.333333
# 7                 West Ham  1.1  ...         5       0    1.333333   2.000000
# 9            Sheffield Utd  1.5  ...         5       1    1.000000   0.666667
# 11               Liverpool  1.6  ...         6       0    1.000000   0.333333
# 12               Tottenham  1.3  ...         5       0    1.000000   0.666667
# ...                    ...  ...  ...       ...     ...         ...        ...
# 42          Crystal Palace  2.3  ...         0       0    2.333333   1.333333
# 44                 Burnley  1.8  ...         5       1    1.666667   0.333333
# 46               Liverpool  2.0  ...         6       0    2.000000   0.333333
# 49                Brighton  1.2  ...         2       1    1.333333   0.666667
# 50                 Watford  3.0  ...         5       1    2.333333   0.666667
#
#            sh_rolling sot_rolling dist_rolling  fk_rolling  pk_rolling  \
# Unnamed: 0
# 5           17.333333    4.666667    18.900000    1.333333    0.333333
# 7           17.333333    3.666667    17.733333    0.666667    0.000000
# 9           16.666667    4.333333    18.233333    0.666667    0.000000
# 11          14.333333    6.666667    18.466667    1.000000    0.000000
# 12          12.000000    5.666667    19.366667    1.000000    0.000000
# ...               ...         ...          ...         ...         ...
# 42          19.000000    7.000000    15.366667    0.333333    0.333333
# 44          18.333333    7.333333    16.000000    0.333333    0.000000
# 46          20.000000    6.666667    16.133333    0.333333    0.000000
# 49          15.666667    4.666667    16.700000    0.333333    0.000000
# 50          15.333333    5.000000    17.200000    0.333333    0.000000
#
#             pkatt_rolling
# Unnamed: 0
# 5                0.333333
# 7                0.000000
# 9                0.000000
# 11               0.000000
# 12               0.333333
# ...                   ...
# 42               0.333333
# 44               0.000000
# 46               0.000000
# 49               0.000000
# 50               0.000000
#
# [68 rows x 38 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9624\1738758534.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                                          date   time         round  day venue  \
# team                    Unnamed: 0
# Arsenal                 6          2020-10-04  14:00   Matchweek 4  Sun  Home
#                         7          2020-10-17  17:30   Matchweek 5  Sat  Away
#                         9          2020-10-25  19:15   Matchweek 6  Sun  Home
#                         11         2020-11-01  16:30   Matchweek 7  Sun  Away
#                         13         2020-11-08  19:15   Matchweek 8  Sun  Home
# ...                                       ...    ...           ...  ...   ...
# Wolverhampton Wanderers 32         2022-03-13  14:00  Matchweek 29  Sun  Away
#                         33         2022-03-18  20:00  Matchweek 30  Fri  Home
#                         34         2022-04-02  15:00  Matchweek 31  Sat  Home
#                         35         2022-04-08  20:00  Matchweek 32  Fri  Away
#                         36         2022-04-24  14:00  Matchweek 34  Sun  Away
#
#                                    result   gf   ga         opponent   xg  \
# team                    Unnamed: 0
# Arsenal                 6               W  2.0  1.0    Sheffield Utd  0.4
#                         7               L  0.0  1.0  Manchester City  0.9
#                         9               L  0.0  1.0   Leicester City  0.9
#                         11              W  1.0  0.0   Manchester Utd  1.1
#                         13              L  0.0  3.0      Aston Villa  1.5
# ...                                   ...  ...  ...              ...  ...
# Wolverhampton Wanderers 32              W  1.0  0.0          Everton  0.8
#                         33              L  2.0  3.0     Leeds United  0.8
#                         34              W  2.0  1.0      Aston Villa  1.2
#                         35              L  0.0  1.0    Newcastle Utd  0.3
#                         36              L  0.0  1.0          Burnley  0.7
#
#                                     ...  day_code  target  gf_rolling  \
# team                    Unnamed: 0  ...
# Arsenal                 6           ...         6       1    2.000000
#                         7           ...         5       0    1.666667
#                         9           ...         6       0    1.000000
#                         11          ...         6       1    0.666667
#                         13          ...         6       0    0.333333
# ...                                 ...       ...     ...         ...
# Wolverhampton Wanderers 32          ...         6       1    1.333333
#                         33          ...         4       0    1.666667
#                         34          ...         5       1    2.333333
#                         35          ...         4       0    1.666667
#                         36          ...         6       0    1.333333
#
#                                    ga_rolling sh_rolling sot_rolling  \
# team                    Unnamed: 0
# Arsenal                 6            1.333333   7.666667    3.666667
#                         7            1.666667   5.333333    3.666667
#                         9            1.666667   7.000000    3.666667
#                         11           1.000000   9.666667    4.000000
#                         13           0.666667   9.666667    2.666667
# ...                                       ...        ...         ...
# Wolverhampton Wanderers 32           1.000000  12.333333    3.666667
#                         33           0.666667  12.333333    4.333333
#                         34           1.000000  13.000000    5.333333
#                         35           1.333333  13.000000    5.000000
#                         36           1.666667  10.000000    4.666667
#
#                                    dist_rolling  fk_rolling  pk_rolling  \
# team                    Unnamed: 0
# Arsenal                 6             14.733333    0.666667    0.000000
#                         7             15.766667    0.000000    0.000000
#                         9             16.733333    0.666667    0.000000
#                         11            16.033333    1.000000    0.000000
#                         13            18.033333    1.000000    0.333333
# ...                                         ...         ...         ...
# Wolverhampton Wanderers 32            19.300000    0.000000    0.000000
#                         33            19.600000    0.000000    0.000000
#                         34            19.833333    0.000000    0.000000
#                         35            18.533333    0.000000    0.000000
#                         36            17.633333    0.000000    0.000000
#
#                                     pkatt_rolling
# team                    Unnamed: 0
# Arsenal                 6                0.000000
#                         7                0.000000
#                         9                0.000000
#                         11               0.000000
#                         13               0.333333
# ...                                           ...
# Wolverhampton Wanderers 32               0.000000
#                         33               0.000000
#                         34               0.000000
#                         35               0.000000
#                         36               0.000000
#
# [1317 rows x 38 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#                  date   time         round  day venue result   gf   ga  \
# Unnamed: 0
# 6          2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 7          2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 9          2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 11         2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 13         2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ...               ...    ...           ...  ...   ...    ...  ...  ...
# 32         2022-03-13  14:00  Matchweek 29  Sun  Away      W  1.0  0.0
# 33         2022-03-18  20:00  Matchweek 30  Fri  Home      L  2.0  3.0
# 34         2022-04-02  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
# 35         2022-04-08  20:00  Matchweek 32  Fri  Away      L  0.0  1.0
# 36         2022-04-24  14:00  Matchweek 34  Sun  Away      L  0.0  1.0
#
#                    opponent   xg  ...  day_code  target  gf_rolling  \
# Unnamed: 0                        ...
# 6             Sheffield Utd  0.4  ...         6       1    2.000000
# 7           Manchester City  0.9  ...         5       0    1.666667
# 9            Leicester City  0.9  ...         6       0    1.000000
# 11           Manchester Utd  1.1  ...         6       1    0.666667
# 13              Aston Villa  1.5  ...         6       0    0.333333
# ...                     ...  ...  ...       ...     ...         ...
# 32                  Everton  0.8  ...         6       1    1.333333
# 33             Leeds United  0.8  ...         4       0    1.666667
# 34              Aston Villa  1.2  ...         5       1    2.333333
# 35            Newcastle Utd  0.3  ...         4       0    1.666667
# 36                  Burnley  0.7  ...         6       0    1.333333
#
#            ga_rolling sh_rolling sot_rolling dist_rolling  fk_rolling  \
# Unnamed: 0
# 6            1.333333   7.666667    3.666667    14.733333    0.666667
# 7            1.666667   5.333333    3.666667    15.766667    0.000000
# 9            1.666667   7.000000    3.666667    16.733333    0.666667
# 11           1.000000   9.666667    4.000000    16.033333    1.000000
# 13           0.666667   9.666667    2.666667    18.033333    1.000000
# ...               ...        ...         ...          ...         ...
# 32           1.000000  12.333333    3.666667    19.300000    0.000000
# 33           0.666667  12.333333    4.333333    19.600000    0.000000
# 34           1.000000  13.000000    5.333333    19.833333    0.000000
# 35           1.333333  13.000000    5.000000    18.533333    0.000000
# 36           1.666667  10.000000    4.666667    17.633333    0.000000
#
#             pk_rolling  pkatt_rolling
# Unnamed: 0
# 6             0.000000       0.000000
# 7             0.000000       0.000000
# 9             0.000000       0.000000
# 11            0.000000       0.000000
# 13            0.333333       0.333333
# ...                ...            ...
# 32            0.000000       0.000000
# 33            0.000000       0.000000
# 34            0.000000       0.000000
# 35            0.000000       0.000000
# 36            0.000000       0.000000
#
# [1317 rows x 38 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          0 2022-01-23  Arsenal         Burnley      D
# 56       1          0 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          1 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#     result_x new_team_x  actual_y  predicted_y                   team_y  \
# 0          D    Arsenal         0            0                  Burnley
# 1          W    Arsenal         0            0  Wolverhampton Wanderers
# 2          W    Arsenal         0            0                Brentford
# 3          W    Arsenal         0            0  Wolverhampton Wanderers
# 4          W    Arsenal         0            0                  Watford
# ..       ...        ...       ...          ...                      ...
# 257        W     Wolves         0            0                  Everton
# 258        L     Wolves         1            0             Leeds United
# 259        W     Wolves         0            0              Aston Villa
# 260        L     Wolves         1            0         Newcastle United
# 261        L     Wolves         1            0                  Burnley
#
#     opponent_y result_y     new_team_y
# 0      Arsenal        D        Burnley
# 1      Arsenal        L         Wolves
# 2      Arsenal        L      Brentford
# 3      Arsenal        L         Wolves
# 4      Arsenal        L        Watford
# ..         ...      ...            ...
# 257     Wolves        L        Everton
# 258     Wolves        W   Leeds United
# 259     Wolves        L    Aston Villa
# 260     Wolves        W  Newcastle Utd
# 261     Wolves        W        Burnley
#
# [262 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64
